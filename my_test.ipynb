# %%
import lhd_retrieve
import numpy as np
import matplotlib.pyplot as plt
retriever = lhd_retrieve.LHDRetriever()

# %%
data = retriever.retrieve_data(
    diag_name="mwscat",
    shot=183646,
    subshot=1, 
    channel=1,
    time_axis=True,
)

# %%
data2 = retriever.retrieve_data(
    diag_name="CTSfosc1",
    shot=183646,
    subshot=1, 
    channel=1,
    time_axis=False,
    dtype=np.int8,
)

# %%
plt.plot(data2.val[::10000])

# %%
plt.plot(data.time[::10000],data.data[::10000]*0.00030517578125)

# %%
plt.plot(data.data[::10000]*0.00030517578125)
plt.plot(data2.data[::10000])
